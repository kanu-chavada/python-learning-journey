# %%
# my first code
print("hello world")
print("learning python....")
# Out:
# hello world
# learning python....

# %%
# variable in python
_name="kanu"
_age=35
PI=3.14

print(_name,_age,PI)
# Out:
# kanu 35 3.14

# %%
# data type in python
print(type(_name))
print(type(_age))
print(type(PI))
isprime=True
print(type(isprime))
money=None
print(type(money))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'NoneType'>

# %%
# style to write a variable

tot_price=100  #snake_case
totPrice=110   #camelcase
TotPrice=120   #pascalcase

# %%
#calculate sum of 2 numbers
a=10
b=20

sum_=a+b
print(sum_)
# Out:
# 30

# %%
#arithmetic operator
x=20
y=10

print(x+y)
print(x-y)
print(x*y)
print(x/y)  
print(x%y)  #modulo
print(x**y)
# Out:
# 30
# 10
# 200
# 2.0
# 0
# 10240000000000

# %%
#relational operater
print(x>y)
print(x<y)
print(x>=y)
print(x<=y)
print(x==y)
print(x!=y)
# Out:
# True
# False
# True
# False
# False
# True

# %%
#assignment operater
s=20
s+=1
print(s)
s-=1
print(s)
s*=2
print(s)
s/=2
print(s)
s**=2
print(s)
# Out:
# 21
# 20
# 40
# 20.0
# 400.0

# %%
#relational operater
var=False

print(not var)
a=2
b=3

print(a<b and a==b)
print(a!=b or a>b)
# Out:
# True
# False
# True

# %%
#type conversion and type casting
ans1=int(5+10.0)    #casting
print(type(ans1))

ans2=5+10.0       #conversion
print(type(ans2))
# Out:
# <class 'int'>
# <class 'float'>

# %%
#examples
number=int("123")
print(number)

val=bool(10)
print(type(val))
# Out:
# 123
# <class 'bool'>

# %%
#user input
num1=int(input("enter your first number"))
num2=int(input("enter your second number"))

sum1=num1+num2
print(sum1)
# Out:
# enter your first number 10
# enter your second number 20
# 30

# %%
# example average of two number
num1=int(input("enter your first number"))
num2=int(input("enter your second number"))

avg=(num1+num2)/2
print(avg)
# Out:
# enter your first number 10
# enter your second number 30
# 20.0
